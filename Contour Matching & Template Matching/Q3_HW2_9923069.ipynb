# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Define our imshow function 
def imshow(title = "Image", image = None, size = 16):
    w, h = image.shape[0], image.shape[1]
    aspect_ratio = w/h
    plt.figure(figsize=(size * aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# Load & Show our input image
image = cv2.imread('C:/Users/USER/Desktop/Zh/University/Term6/Multimedia/HW/HW2/market.png')
imshow("Original Image", image)

# %%
# Grayscale our image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
copy = image.copy()

# Define Our Template
template = cv2.imread('C:/Users/USER/Desktop/Zh/University/Term6/Multimedia/HW/HW2/1.png', cv2.IMREAD_GRAYSCALE)
w, h = template.shape[::-1]

# Template Matching
res = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF_NORMED)
threshold = 0.8
loc = np.where( res >= threshold)

# Draw Rectangles
for pt in zip(*loc[::-1]):
    cv2.rectangle(copy, pt, (pt[0] + w, pt[1] + h), (0,0,255), 1)
imshow('First Stuff', copy)

# Report the numbers
print("Number of First Stuff =", int(np.ceil((max(loc[1]) - min(loc[1]))/w)))
# Out:
# Number of First Stuff = 2

# %%
# Grayscale our image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
copy2 = image.copy()

# Define Our Template
template2 = cv2.imread('C:/Users/USER/Desktop/Zh/University/Term6/Multimedia/HW/HW2/2.png', cv2.IMREAD_GRAYSCALE)
w2, h2 = template2.shape[::-1]

# Template Matching
res2 = cv2.matchTemplate(gray, template2, cv2.TM_CCOEFF_NORMED)
threshold2 = 0.9
loc2 = np.where( res2 >= threshold2)

# Draw Rectangles
for pt in zip(*loc2[::-1]):
    cv2.rectangle(copy2, pt, (pt[0] + w2, pt[1] + h2), (0,0,255), 1)
imshow('Second Stuff', copy2)

# Report the numbers
print("Number of Second Stuff =", int(np.ceil((max(loc2[1]) - min(loc2[1]))/w)))
# Out:
# Number of Second Stuff = 3
